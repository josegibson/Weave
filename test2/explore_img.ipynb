# %%
import openpyxl
from openpyxl.drawing.image import Image as XLImage
from PIL import Image as PILImage
import io
from IPython.display import display

# Load the Excel workbook
workbook = openpyxl.load_workbook('SCFT MODEL REPORT-1.xlsx')

print(workbook.sheetnames)

# Select the desired sheet
sheet = workbook['Serving PCI Plot']  # Change to your sheet name

# Display images in the sheet
for image in sheet._images:
    pil_img = PILImage.open(image.ref)
    display(pil_img)
# Out:
# ['SCFT MODEL REPORT', 'Drive route ', 'Serving PCI Plot', 'RSRP Plot', 'RSRQ Plot', 'SINR Plot', 'DL Throughputplot', 'Rank Indicator Plot', 'Modulation Plot', 'Prediction Plot-RSRP', 'Prediction Plot-RSR', 'Prediction Plot-SINR', 'Prediction Plot-DL Throughput']
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x666>
